# %%
import numpy as np
import matplotlib.pyplot as plt

# %%
file = np.load("data/MR/data/processed/tiles/marius_hills/marius_hills_r00000_c00000.npz")

print(file.files)
# Out:
# ['image', 'mask', 'row', 'col']

# %%
entries = file.files
file['mask'].shape
# Out:
# (7, 256, 256)
