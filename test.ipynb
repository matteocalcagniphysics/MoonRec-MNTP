# %%
import numpy as np
import matplotlib.pyplot as plt

# %%
file = np.load("/home/matteocalcagni/Desktop/MoonRec-MNTP/data/marius_hills_r00000_c00000.npz")

file.files
# Out:
# ['image', 'mask', 'row', 'col']

# %%
image = file['image']
image.shape
# Out:
# (3, 256, 256)

# %%
plt.imshow(image[0])
